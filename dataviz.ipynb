# %%
import matplotlib.pyplot as plt
from train import load_labels, load_images
from utils import augment_pair
from PIL import Image

img = load_images(["aachen_000003_000019.png"])[0]
lab = load_labels(["aachen_000003_000019.png"])[0]

Image.fromarray(img, "RGB").show()
plt.plot(lab)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 img = load_images(["aachen_000003_000019.png"])[0]
#       6 lab = load_labels(["aachen_000003_000019.png"])[0]
# ----> 8 plt.imshow(img)
#       9 plt.plot(lab)
#
# File ~\miniconda3\envs\vi\lib\site-packages\matplotlib\pyplot.py:3346, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3325 @_copy_docstring_and_deprecators(Axes.imshow)
#    3326 def imshow(
#    3327     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3344     **kwargs,
#    3345 ) -> AxesImage:
# -> 3346     __ret = gca().imshow(
#    3347         X,
#    3348         cmap=cmap,
#    3349         norm=norm,
#    3350         aspect=aspect,
#    3351         interpolation=interpolation,
#    3352         alpha=alpha,
# ...

# %%
img, lab = augment_pair(img, lab, 1)

Image.fromarray(img, "RGB").show
plt.plot(lab)
